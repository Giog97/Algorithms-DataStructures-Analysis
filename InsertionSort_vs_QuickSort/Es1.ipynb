# %%
import main
# Out:
# Array è:
# [182, 566, 270, 265, 970, 502, 393, 633, 70, 39]
#
# Array ordinato con InsertionSort è:
# [39, 70, 182, 265, 270, 393, 502, 566, 633, 970]
#
# Il tempo per eseguire InsertionSort è 0.0002253000000003169
#
# Array ordinato con QuickSort:
# [39, 70, 182, 265, 270, 393, 502, 566, 633, 970]
#
# Il tempo per eseguire QuickSort è 6.96000000015573e-05
